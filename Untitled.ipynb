# %%
import tensorflow as tf
import numpy as np

# %%
def f(x):
    return 3 * x
input = []
output = []
for x in range(10000):
    input.append(x)
    output.append(f(x))

# %%
# parameters
learning_rate = 0.01
