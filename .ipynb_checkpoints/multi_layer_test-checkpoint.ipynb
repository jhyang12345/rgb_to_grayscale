# %%
import tensorflow as tf
import numpy as np

# %%
def f(a, b, c):
    return 3 * a + 2 * b - c
input = []
output = []
for x in range(1000):
    a = np.random.random_sample() * 100
    b = np.random.random_sample() * 100
    c = np.random.random_sample() * 100
    input.append([a, b, c])
    output.append([f(a, b, c)])

# %%
learning_rate = 0.001
epochs = 1000
display_step = 5

# %%
train_X = np.asarray(input)
train_Y = np.asarray(output)
test_X = np.asarray(input[-300:])
test_Y = np.asarray(output[-300:])
n_samples = train_X.shape[0]
print(n_samples)
print(train_X.shape)
# Out:
# 1000
# (1000, 3)

# %%
X = tf.placeholder(tf.float32, shape=[None, 3], name="x-input")
Y = tf.placeholder(tf.float32, shape=[None, 1], name="y-input")

# %%
W1 = tf.Variable(tf.random_uniform([3, 3], -1, 1), name="weight1")
b1 = tf.Variable(tf.random_uniform([1, 3], -1, 1), name="bias1")
W2 = tf.Variable(tf.random_uniform([3, 1], -1, 1), name="weight2")
b2 = tf.Variable(tf.random_uniform([1, 1], -1, 1), name="bias2")

# %%
layer_one = tf.add(tf.matmul(X, W1), b1)
pred = tf.add(tf.matmul(layer_one, W2), b2)
cost = tf.reduce_sum(tf.pow(pred - Y, 2)) / 2 * n_samples
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(epochs):
        for (x, y) in zip(train_X, train_Y):
            input_X = np.asarray([x])
            input_Y = np.asarray([y])
            sess.run(optimizer, feed_dict={X: input_X, Y: input_Y})

    for (x, y) in zip(test_X, test_Y):
        input_X = np.asarray([x])
        input_Y = np.asarray([y])
        test_output = sess.run(pred, feed_dict={X: input_X, Y: input_Y})
        print("Results:", input_Y, test_output)
    
    saver.save(sess, "./tmp/multi_layer.ckpt")
# Out:
# 71496.7
# 49265.6
# 34.3917
# 27.8427
# 100.643
# 14.2231
# 10.3726
# 8.4862
# 8.59229
# 4.98919
# 6615.84
# 618.36
# 3.87456
# 24.5563
# 34903.3
# 0.735367
# 9.94411
# 4.23063
# 8.40467
# 78134.4
# 7.38686
# 3.96431
# 82.9954
# 31.2946
# 3.35751
# 39241.6
# 0.461659
# 122.885
# 9.56497
# 0.531214
# 2.08288
# 8.08652
# 3507.63
# 12.1493
# 8205.92
# 3.45503
# 5.82974
# 2.60001
# 507.552
# 155.203
# 250.669
# 79.6337
# 9.87693
# 8.61464
# 0.0747851
# 159.174
# 13.8348
# 1402.73
# 70.96
# 1463.24
# 224.602
# 2.01599
# 2.99831
# 42921.9
# 79.2042
# 14.4094
# 26.0086
# 25.2447
# 1200.24
# 2360.79
# 0.450148
# 7.73248
# 47.6693
# 714.255
# 347.742
# 12.8883
# 87.2308
# 207.24
# 7.40351
# 0.014681
# 425.6
# 392.25
# 27.4447
# 50.5965
# 0.198456
# 1.31099
# 13.3696
# 188.198
# 0.0664174
# 0.00911363
# 12315.4
# 41.4094
# 8.07528
# 287.085
# 383.631
# 19841.3
# 13.0698
# 1552.38
# 12.9137
# 9.55854
# 6.9646
# 13.6297
# 158.882
# 435.43
# 4.76174
# 55.0841
# 33724.1
# 9.75518
# 0.193514
# 1702.05
# 1378.51
# 2.59843
# 6.79452
# 26.9298
# 336.225
# 157.443
# 89.5922
# 1.96568
# 2.97421
# 0.0454559
# 1800.67
# 1318.39
# 83.3094
# 12.3652
# 15.6557
# 38.8476
# 983.649
# 57.876
# 10039.6
# 3.34861
# 462.095
# 0.0564897
# 24902.1
# 45.7998
# 131.562
# 12.9854
# 237.765
# 57.3425
# 29.5289
# 13.8732
# 12.3285
# 8.43293
# 52.7218
# 0.00823157
# 13.2676
# 38.473
# 14.5395
# 2.51176
# 7.4473
# 4.83584
# 24.7721
# 6.41625
# 21.2636
# 5.48303
# 0.428599
# 0.273242
# 80.2088
# 23.5781
# 0.816267
# 35781.9
# 2.11554
# 3.38118
# 5.8836
# 24.1258
# 11.4398
# 322.827
# 0.0541481
# 13.8762
# 61.6668
# 761.513
# 18.472
# 0.427231
# 37.2864
# 123.611
# 12.8092
# 21.0862
# 3.75658
# 43.5273
# 63.0092
# 22.1439
# 7629.85
# 2.94548
# 31.7888
# 597.323
# 172.568
# 68.5906
# 11.6377
# 14.0479
# 25.4675
# 268.888
# 4.97681
# 1198.53
# 7.46547
# 15805.3
# 242.73
# 4363.46
# 92.0874
# 11609.1
# 11.4958
# 80.9701
# 115.721
# 298.882
# 125.255
# 0.962698
# 11.0313
# 860.283
# 8.89399
# 5.46884
# 315.703
# 133.756
# Results: [[ 207.95123681]] [[ 207.95985413]]
# Results: [[ 322.95376526]] [[ 322.91918945]]
# Results: [[ 270.26561196]] [[ 270.25524902]]
# Results: [[ 382.5087312]] [[ 382.47290039]]
# Results: [[ 217.79436806]] [[ 217.79672241]]
# Results: [[ 186.28539393]] [[ 186.26664734]]
# Results: [[ 23.41553053]] [[ 23.40625]]
# Results: [[ 142.79552294]] [[ 142.77806091]]
# Results: [[ 120.87422637]] [[ 120.87729645]]
# Results: [[ 100.02249771]] [[ 100.01262665]]
# Results: [[ 55.65228792]] [[ 55.64296722]]
# Results: [[ 275.64162678]] [[ 275.64788818]]
# Results: [[ 339.02548393]] [[ 339.00405884]]
# Results: [[ 17.04922929]] [[ 17.04579353]]
# Results: [[ 286.43841867]] [[ 286.43838501]]
# Results: [[ 105.36127061]] [[ 105.36685181]]
# Results: [[ 44.18631378]] [[ 44.17173386]]
# Results: [[ 354.58850608]] [[ 354.56384277]]
# Results: [[ 442.16462809]] [[ 442.14093018]]
# Results: [[ 96.42353123]] [[ 96.40833282]]
# Results: [[ 169.72648005]] [[ 169.72938538]]
# Results: [[ 296.21906992]] [[ 296.20419312]]
# Results: [[ 374.92012729]] [[ 374.89163208]]
# Results: [[ 224.38496103]] [[ 224.37191772]]
# Results: [[ 27.42025954]] [[ 27.44030571]]
# Results: [[ 151.67825903]] [[ 151.68493652]]
# Results: [[ 70.91872538]] [[ 70.93057251]]
# Results: [[ 95.7001612]] [[ 95.70472717]]
# Results: [[ 217.28982021]] [[ 217.27189636]]
# Results: [[ 138.18025739]] [[ 138.17530823]]
# Results: [[ 292.71646926]] [[ 292.7008667]]
# Results: [[ 81.88983796]] [[ 81.89292145]]

# %%
tf.reset_default_graph()
W1 = tf.Variable(tf.random_uniform([3, 3], -1, 1), name="weight1")
b1 = tf.Variable(tf.random_uniform([1, 3], -1, 1), name="bias1")
W2 = tf.Variable(tf.random_uniform([3, 1], -1, 1), name="weight2")
b2 = tf.Variable(tf.random_uniform([1, 1], -1, 1), name="bias2")
with tf.Session() as sess:
    saver.restore(sess, "./tmp/multi_layer.ckpt")
# Out:
# INFO:tensorflow:Restoring parameters from ./tmp/multi_layer.ckpt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\USER\AppData\Local\conda\conda\envs\tflearn\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1067             subfeed_t = self.graph.as_graph_element(subfeed, allow_tensor=True,
# -> 1068                                                     allow_operation=False)
#    1069           except Exception as e:
#
# C:\Users\USER\AppData\Local\conda\conda\envs\tflearn\lib\site-packages\tensorflow\python\framework\ops.py in as_graph_element(self, obj, allow_tensor, allow_operation)
#    2707     with self._lock:
# -> 2708       return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    2709
#
# C:\Users\USER\AppData\Local\conda\conda\envs\tflearn\lib\site-packages\tensorflow\python\framework\ops.py in _as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    2749                          "exist. The operation, %s, does not exist in the "
# -> 2750                          "graph." % (repr(name), repr(op_name)))
#    2751         try:
#
# KeyError: "The name 'save_1/Const:0' refers to a Tensor which does not exist. The operation, 'save_1/Const', does not exist in the graph."
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-df951ff070c5> in <module>()
#       5 b2 = tf.Variable(tf.random_uniform([1, 1], -1, 1), name="bias2")
#       6 with tf.Session() as sess:
# ----> 7     saver.restore(sess, "./tmp/multi_layer.ckpt")
#       8
#
# C:\Users\USER\AppData\Local\conda\conda\envs\tflearn\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1558     logging.info("Restoring parameters from %s", save_path)
#    1559     sess.run(self.saver_def.restore_op_name,
# -> 1560              {self.saver_def.filename_tensor_name: save_path})
#    1561
#    1562   @staticmethod
#
# C:\Users\USER\AppData\Local\conda\conda\envs\tflearn\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Users\USER\AppData\Local\conda\conda\envs\tflearn\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1069           except Exception as e:
#    1070             raise TypeError('Cannot interpret feed_dict key as Tensor: '
# -> 1071                             + e.args[0])
#    1072
#    1073           if isinstance(subfeed_val, ops.Tensor):
#
# TypeError: Cannot interpret feed_dict key as Tensor: The name 'save_1/Const:0' refers to a Tensor which does not exist. The operation, 'save_1/Const', does not exist in the graph.
